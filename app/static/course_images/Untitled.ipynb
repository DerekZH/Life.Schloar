# %%
import os

# %%
files = os.listdir('.')

# %%
for f in files:
    if 'Create_Your_WebBrowser:_Learn_C#_Fundamentals_Practically.jpg' == f:
        print f
    break

# %%
files
# Out:
# ['-dracula-by-bram-stoker-berkeleyx-book-club_378x225.jpg',
#  '-pride-and-prejudice-by-jane-austen-berkeleyx-book-club_378x225.jpg',
#  '-the-jungle-by-upton-sinclair-berkeleyx-book-club_378x225.jpg',
#  '.ipynb_checkpoints',
#  '0.png',
#  '000x-course_image-378x225a.png',
#  '003x-course_card_image-378x225.png',
#  '00690242.1x-course_image-378x225.png',
#  '10.03x-378x225a.png',
#  '100_Ways_to_Pass_the_Chemistry_Regents.jpg',
#  '1024px-Francois_Dubois_001.jpg',
#  '10_Courses_In_1_-_The_Holy_Grail_For_Photoshop_Retouching.jpg',
#  '10_minutes_to_know_Beijing.jpg',
#  '10_Numbers_Every_Business_Owner_Should_Know.jpg',
#  '10_Step_Startup:_The_Complete_Entrepreneurship_Course_Online.jpg',
#  '10_Steps_to_Dramatic_Nature_Photography.jpg',
#  '10_Tips_To_Build_&_Sell_WordPress_Plugins.jpg',
#  '11-132x-design-378x225.jpg',
#  '11.133x-implementation_and_evaluation_of_educational_technology-378x225.png',
#  '12_Lead_Generation_Strategies_-_Used_By_Sales_Experts.jpg',
# ...
